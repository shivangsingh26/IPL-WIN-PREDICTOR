# %%
import pandas as pd
import numpy as np

# %%
deli = pd.read_csv("/content/deliveries.csv")
mat = pd.read_csv("/content/matches.csv")

# %%
deli.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
deli.loc[deli.match_id == 306]
# Out:
#        match_id  inning                 batting_team  \
# 71973       306       1  Royal Challengers Bangalore
# 71974       306       1  Royal Challengers Bangalore
# 71975       306       1  Royal Challengers Bangalore
# 71976       306       1  Royal Challengers Bangalore
# 71977       306       1  Royal Challengers Bangalore
# ...         ...     ...                          ...
# 72219       306       2               Mumbai Indians
# 72220       306       2               Mumbai Indians
# 72221       306       2               Mumbai Indians
# 72222       306       2               Mumbai Indians
# 72223       306       2               Mumbai Indians
#
#                       bowling_team  over  ball     batsman non_striker  \
# 71973               Mumbai Indians     1     1  MA Agarwal    CH Gayle
# 71974               Mumbai Indians     1     2    CH Gayle  MA Agarwal
# 71975               Mumbai Indians     1     3    CH Gayle  MA Agarwal
# ...

# %%
deli['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
deli.tail()
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deli['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
deli.loc[deli['dismissal_kind']=='caught']
# Out:
#         match_id  inning                 batting_team  \
# 11             1       1          Sunrisers Hyderabad
# 64             1       1          Sunrisers Hyderabad
# 94             1       1          Sunrisers Hyderabad
# 165            1       2  Royal Challengers Bangalore
# 206            1       2  Royal Challengers Bangalore
# ...          ...     ...                          ...
# 178908     11415       1               Mumbai Indians
# 178921     11415       1               Mumbai Indians
# 178945     11415       1               Mumbai Indians
# 179019     11415       2          Chennai Super Kings
# 179067     11415       2          Chennai Super Kings
#
#                        bowling_team  over  ball       batsman   non_striker  \
# 11      Royal Challengers Bangalore     2     5     DA Warner      S Dhawan
# 64      Royal Challengers Bangalore    11     3      S Dhawan  MC Henriques
# 94      Royal Challengers Bangalore    16     2  MC Henriques  Yuvraj Singh
# ...

# %%
deli.loc[deli.match_id ==1].loc[deli.inning==2].total_runs.sum()
# Out:
# 172

# %%
deli.is_super_over.unique()
# Out:
# array([0, 1])

# %%
deli.loc[deli.is_super_over==1].loc[deli.over==1].loc[deli.ball==1]
# Out:
#         match_id  inning                 batting_team  \
# 8092          34       3               Mumbai Indians
# 8097          34       4                Gujarat Lions
# 29279        126       3        Kolkata Knight Riders
# 29286        126       4             Rajasthan Royals
# 44819        190       3          Chennai Super Kings
# 44824        190       4              Kings XI Punjab
# 91904        388       3          Sunrisers Hyderabad
# 91911        388       4  Royal Challengers Bangalore
# 95073        401       3  Royal Challengers Bangalore
# 95079        401       4             Delhi Daredevils
# 112912       476       3        Kolkata Knight Riders
# 112918       476       4             Rajasthan Royals
# 127359       536       3              Kings XI Punjab
# 127366       536       4             Rajasthan Royals
#
#                        bowling_team  over  ball           batsman  \
# 8092                  Gujarat Lions     1     1        JC Buttler
# ...

# %%
df1= deli.loc[deli.match_id==190].loc[deli.inning==1].total_runs.sum()
df2= deli.loc[deli.match_id==190].loc[deli.inning==2].total_runs.sum()
if df1>df2:
  print("Match won by:",deli.loc[deli.match_id==190].loc[deli.inning==3].batting_team)
else:
    print("Match won by:",deli.loc[deli.match_id==190].loc[deli.inning==4].batting_team)
# Out:
# Match won by: 44824    Kings XI Punjab
# 44825    Kings XI Punjab
# 44826    Kings XI Punjab
# 44827    Kings XI Punjab
# Name: batting_team, dtype: object

# %%
deli.shape
# Out:
# (179078, 21)

# %%
mat.head(10)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8   9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 9  10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
mat.result.unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
mat.dl_applied.unique()
# Out:
# array([0, 1])

# %%
mat.loc[mat.winner == 'Sunrisers Hyderabad'].value_counts()
# Out:
# id     Season    city       date        team1                  team2                        toss_winner                  toss_decision  result  dl_applied  winner               win_by_runs  win_by_wickets  player_of_match  venue                                      umpire1          umpire2                umpire3
# 7897   IPL-2018  Hyderabad  09-04-2018  Rajasthan Royals       Sunrisers Hyderabad          Sunrisers Hyderabad          field          normal  0           Sunrisers Hyderabad  0            9               S Dhawan         Rajiv Gandhi International Stadium, Uppal  Nigel Llong      Vineet Kulkarni        O Nandan                 1
# 7900   IPL-2018  Hyderabad  12-04-2018  Mumbai Indians         Sunrisers Hyderabad          Sunrisers Hyderabad          field          normal  0           Sunrisers Hyderabad  0            1               Rashid Khan      Rajiv Gandhi International Stadium, Uppal  O Nandan         Nigel Llong            Vineet Kulkarni          1
# ...

# %%
mat.pivot_table(index = ['win_by_wickets', 'win_by_runs'], aggfunc ='size')
# Out:
# win_by_wickets  win_by_runs
# 0               0              13
#                 1              10
#                 2               7
#                 3               5
#                 4              11
#                                ..
# 6               0              85
# 7               0              80
# 8               0              54
# 9               0              37
# 10              0              11
# Length: 99, dtype: int64

# %% [markdown]
# WE NEED TO MAKE OUR CUSTOM TABLE FOR MODELLING
# THE FEATURES WHICH WE WILL NEED ARE : BATTING_TEAM , BOWLING_TEAM ,
# CITY ,
# RUNS_LEFT ,
# BALLS_LEFT ,
# WICKETS_LEFT
# TOTAL_RUNS,
# CRR ,
# RRR ,
# RESULT

# %%
#FIRST FINDING TOTAL RUNS SCORED IN EACH INNINGS OF EACH MATCH
total_score_df = deli.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
total_score_df
# Out:
# <ipython-input-19-e85cb149e94d>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score_df = deli.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
#We need only for first innings
total_score_df = total_score_df[total_score_df['inning']==1]

# %%
mat_df = mat.merge(total_score_df[['match_id','total_runs']],left_on = 'id',right_on = 'match_id')

# %%
mat_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
mat_df.shape
# Out:
# (756, 20)

# %%
teams = mat_df.team1.unique()

# %%
mat_df['team1'].value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
teams = ['Sunrisers Hyderabad',
         'Mumbai Indians',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
         'Kings XI Punjab',
       'Chennai Super Kings',
         'Rajasthan Royals',
       'Delhi Capitals']

# %%
mat_df['team1']=mat_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
mat_df['team2']=mat_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
mat_df['team1']=mat_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
mat_df['team2']=mat_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
mat_df.team1.value_counts()
# Out:
# Sunrisers Hyderabad            106
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Capitals                  78
# Rajasthan Royals                67
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Name: team1, dtype: int64

# %%
mat_df = mat_df[mat_df['team1'].isin(teams)]
mat_df = mat_df[mat_df['team2'].isin(teams)]

# %%
mat_df.team1.value_counts()
# Out:
# Sunrisers Hyderabad            97
# Mumbai Indians                 92
# Kings XI Punjab                83
# Chennai Super Kings            83
# Royal Challengers Bangalore    76
# Kolkata Knight Riders          76
# Delhi Capitals                 70
# Rajasthan Royals               64
# Name: team1, dtype: int64

# %%
mat_df.shape
# Out:
# (641, 20)

# %%
mat_df['dl_applied'].value_counts()
# Out:
# 0    626
# 1     15
# Name: dl_applied, dtype: int64

# %%
#Keeping only those matches which are not rain affected
mat_df = mat_df[mat_df['dl_applied'] == 0]

# %%
#We require only few elements from mat_df
mat_df = mat_df[['match_id','city','winner','total_runs']]

# %%
deli_df = mat_df.merge(deli, on='match_id')

# %%
deli_df = deli_df[deli_df.inning == 2]

# %%
deli_df.shape
# Out:
# (72413, 24)

# %%
#We require runs left coloumn now
#which can be written as total runs - runs upto the inputted stage of the match
deli_df['curr_score'] = deli_df.groupby('match_id').cumsum()['total_runs_y'] #gives score upto the given point of the match
# Out:
# <ipython-input-38-352b5586b65e>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   deli_df['curr_score'] = deli_df.groupby('match_id').cumsum()['total_runs_y'] #gives score upto the given point of the match

# %%
#as we have found the current score of the match we just need to subtract it by target runs
deli_df['runs_left'] = deli_df['total_runs_x'] - deli_df['curr_score']

# %%
deli_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deli_df['balls_left'] = 126 - (deli_df['over']*6 + deli_df['ball'])
deli_df.tail()
# Out:
#         match_id       city          winner  total_runs_x  inning  \
# 149573     11415  Hyderabad  Mumbai Indians           152       2
# 149574     11415  Hyderabad  Mumbai Indians           152       2
# 149575     11415  Hyderabad  Mumbai Indians           152       2
# 149576     11415  Hyderabad  Mumbai Indians           152       2
# 149577     11415  Hyderabad  Mumbai Indians           152       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        penalty_runs batsman_runs  extra_runs  total_runs_y  player_dismissed  \
# ...

# %%
deli_df['player_dismissed'] = deli_df['player_dismissed'].fillna('0')
deli_df['player_dismissed'] = deli_df['player_dismissed'].apply(lambda x : x if x=='0' else '1')
deli_df['player_dismissed'] = deli_df['player_dismissed'].astype('int')
wickets = deli_df.groupby('match_id').cumsum()['player_dismissed'].values
deli_df['wickets'] = 10 - wickets
deli_df.tail(20)
# Out:
# <ipython-input-42-1278f4250890>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = deli_df.groupby('match_id').cumsum()['player_dismissed'].values
#         match_id       city          winner  total_runs_x  inning  \
# 149558     11415  Hyderabad  Mumbai Indians           152       2
# 149559     11415  Hyderabad  Mumbai Indians           152       2
# 149560     11415  Hyderabad  Mumbai Indians           152       2
# 149561     11415  Hyderabad  Mumbai Indians           152       2
# 149562     11415  Hyderabad  Mumbai Indians           152       2
# 149563     11415  Hyderabad  Mumbai Indians           152       2
# 149564     11415  Hyderabad  Mumbai Indians           152       2
# 149565     11415  Hyderabad  Mumbai Indians           152       2
# ...

# %%
#simply now crr = runs/overs
deli_df['crr'] = deli_df['curr_score']*6/(120 - deli_df['balls_left'])

# %%
deli_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... extra_runs total_runs_y  player_dismissed  \
# 125       CH Gayle  ...          0            1                 0
# ...

# %%
#now finding rrr
deli_df['rrr'] = (deli_df['runs_left']*6)/deli_df['balls_left']

# %%
def winner(row):
  return 1 if row['batting_team'] == row['winner'] else 0

# %%
deli_df['result'] = deli_df.apply(winner,axis=1) #apply used to apply the function to every single row of the df

# %%
#lets print our desired dataframe now
final_df = deli_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
#Now to avoid bias as all balls are in order, so we will shuffle the data frame using pandas sample method
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                batting_team    bowling_team       city  runs_left  balls_left  \
# 115654  Sunrisers Hyderabad  Mumbai Indians  Hyderabad         82          63
#
#         wickets  total_runs_x       crr       rrr  result
# 115654        9           142  6.315789  7.809524       1

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               7
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left'] !=0]

# %%
#Now as we are done with data preprocessing we will build a model now
from sklearn.model_selection import train_test_split
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#As some of our coloumns batting_team,bowling_team,city are strings so we will apply one hot encoding on it
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
#If we use Logistic Regression
pipe1 = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
#If we use random forest classifier
pipe2 = Pipeline(steps=[
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

# %%
final_df = final_df[final_df['balls_left'] !=0]

# %%
pipe1.fit(X_train,y_train)
pipe2.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
# ...

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  57073.000000  57073.000000  57073.000000  57073.000000  57073.000000
# mean      92.690537     62.910238      7.553712    165.738703      7.444141
# std       49.964481     33.282541      2.125980     29.316356      2.283369
# min      -12.000000     -2.000000      0.000000     65.000000      0.000000
# 25%       53.000000     35.000000      6.000000    147.000000      6.255319
# 50%       92.000000     64.000000      8.000000    165.000000      7.484536
# 75%      130.000000     92.000000      9.000000    185.000000      8.697248
# max      249.000000    119.000000     10.000000    250.000000     42.000000
#
#                 rrr
# count  57073.000000
# mean      10.347937
# std       13.979769
# min     -510.000000
# 25%        7.153846
# 50%        8.886076
# 75%       10.901408
# max      678.000000

# %%
final_df = final_df[final_df['balls_left'] !=0]

# %%
y_pred1 = pipe1.predict(X_test)
y_pred2 = pipe2.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
a1 = accuracy_score(y_test,y_pred1)
a2 = accuracy_score(y_test,y_pred2)

# %%
print(f'Accuracy Score using Logistic Regression = {a1}')
print(f"Accuracy Score using Random Forest Regression = {a2}")
# Out:
# Accuracy Score using Logistic Regression = 0.8046113953325391
# Accuracy Score using Random Forest Regression = 0.9990889340528418

# %%
 pipe1.predict_proba(X_test)[3]
# Out:
# array([0.32015634, 0.67984366])

# %%
pipe2.predict_proba(X_test)[6]
# Out:
# array([1., 0.])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)

    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]

    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(deli_df,74,pipe2)
temp_df
# Out:
# Target- 178
#        end_of_over  runs_after_over  wickets_in_over   lose   win
# 10459            1                4                0   99.0   1.0
# 10467            2                8                0   99.0   1.0
# 10473            3                1                0   96.0   4.0
# 10479            4                7                1   99.0   1.0
# 10485            5               12                0   99.0   1.0
# 10491            6               13                0   98.0   2.0
# 10497            7                9                0  100.0   0.0
# 10505            8               15                0   99.0   1.0
# 10511            9                7                0   96.0   4.0
# 10518           10               17                0   94.0   6.0
# 10524           11                9                1   95.0   5.0
# 10530           12                9                0   97.0   3.0
# 10536           13                8                0   95.0   5.0
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
deli_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle
pickle.dump(pipe2,open('pipe.pkl','wb'))
